# %%
import re 
import pandas as pd

# %%
f=open("WhatsApp Chat with Gear_up.txt",encoding='utf-8')
data=f.read()
print(data)
# Out:
# 21/03/2023, 09:05 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 21/03/2023, 09:05 - You created group "Gear_up"
# 21/03/2023, 09:05 - You added Shubam Hostel
# 21/03/2023, 09:05 - Prakhar :): Guys
# 21/03/2023, 09:05 - Prakhar :): We cant live a normal life
# 21/03/2023, 09:06 - Prakhar :): Theie are people dealing in  crores
# 21/03/2023, 09:06 - Prakhar :): Their *
# 21/03/2023, 09:06 - Prakhar :): We need to start earninf money
# 21/03/2023, 09:06 - Prakhar :): Lets do something ASAP
# 21/03/2023, 09:06 - Prakhar :): Market is full of opportunities
# 21/03/2023, 09:06 - Prakhar :): Lets put in somethingb
# 21/03/2023, 09:07 - Prakhar :): High time
# We cant just sit everyday living a normal fucking life
# 21/03/2023, 09:07 - Prakhar :): We need to come up with something
# 21/03/2023, 09:07 - Prakhar :): There are students earning 50k per month
# ...

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'
messages = re.split(pattern, data)[1:]
len(messages)
# Out:
# 21095

# %%
dates = re.findall(pattern, data)
len(dates)
print(dates[1:4])
# Out:
# ['21/03/2023, 09:05 - ', '21/03/2023, 09:05 - ', '21/03/2023, 09:05 - ']

# %%
df=pd.DataFrame({'u_messages':messages,'m_dates':dates})
#convert msg datatype
df['m_dates']=pd.to_datetime(df['m_dates'], format='%d/%m/%Y, %H:%M - ')
